# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import RandomizedSearchCV


pd.set_option('display.max_columns', None)

# %%
df_81_train = pd.read_csv('/Users/siucheung/School/Modern Data Analytics/Modern-Data-Analytics-Backend/Dataset/train/train_night_81.csv',
                             usecols=['result_timestamp','laeq','night_scale','night_hour','Date','Event_type',
                                    'Weight_Event_Type','Organizer','Respondents','Distance',
                                    'LC_HUMIDITY','LC_DWPTEMP','LC_WINDSPEED','weekday',
                                    'Holiday','downseason','Weight_respondent','Total_Event_Score'])
calverie_train = pd.read_csv('/Users/siucheung/School/Modern Data Analytics/Modern-Data-Analytics-Backend/Dataset/train/train_night_calverie.csv',
                             usecols=['result_timestamp','laeq','night_scale','night_hour','Date','Event_type',
                                    'Weight_Event_Type','Organizer','Respondents','Distance',
                                    'LC_HUMIDITY','LC_DWPTEMP','LC_WINDSPEED','weekday',
                                    'Holiday','downseason','Weight_respondent','Total_Event_Score'])
filosovia_train = pd.read_csv('/Users/siucheung/School/Modern Data Analytics/Modern-Data-Analytics-Backend/Dataset/train/train_night_filosovia.csv',
                             usecols=['result_timestamp','laeq','night_scale','night_hour','Date','Event_type',
                                    'Weight_Event_Type','Organizer','Respondents','Distance',
                                    'LC_HUMIDITY','LC_DWPTEMP','LC_WINDSPEED','weekday',
                                    'Holiday','downseason','Weight_respondent','Total_Event_Score'])
maxim_train = pd.read_csv('/Users/siucheung/School/Modern Data Analytics/Modern-Data-Analytics-Backend/Dataset/train/train_night_maxim.csv',
                             usecols=['result_timestamp','laeq','night_scale','night_hour','Date','Event_type',
                                    'Weight_Event_Type','Organizer','Respondents','Distance',
                                    'LC_HUMIDITY','LC_DWPTEMP','LC_WINDSPEED','weekday',
                                    'Holiday','downseason','Weight_respondent','Total_Event_Score'])
taste_train = pd.read_csv('/Users/siucheung/School/Modern Data Analytics/Modern-Data-Analytics-Backend/Dataset/train/train_night_taste.csv',
                             usecols=['result_timestamp','laeq','night_scale','night_hour','Date','Event_type',
                                    'Weight_Event_Type','Organizer','Respondents','Distance',
                                    'LC_HUMIDITY','LC_DWPTEMP','LC_WINDSPEED','weekday',
                                    'Holiday','downseason','Weight_respondent','Total_Event_Score'])
vrijthof_train = pd.read_csv('/Users/siucheung/School/Modern Data Analytics/Modern-Data-Analytics-Backend/Dataset/train/train_night_vrijthof.csv',
                             usecols=['result_timestamp','laeq','night_scale','night_hour','Date','Event_type',
                                    'Weight_Event_Type','Organizer','Respondents','Distance',
                                    'LC_HUMIDITY','LC_DWPTEMP','LC_WINDSPEED','weekday',
                                    'Holiday','downseason','Weight_respondent','Total_Event_Score'])
xior_train = pd.read_csv('/Users/siucheung/School/Modern Data Analytics/Modern-Data-Analytics-Backend/Dataset/train/train_night_xior.csv',
                             usecols=['result_timestamp','laeq','night_scale','night_hour','Date','Event_type',
                                    'Weight_Event_Type','Organizer','Respondents','Distance',
                                    'LC_HUMIDITY','LC_DWPTEMP','LC_WINDSPEED','weekday',
                                    'Holiday','downseason','Weight_respondent','Total_Event_Score'])

df_81_test = pd.read_csv('/Users/siucheung/School/Modern Data Analytics/Modern-Data-Analytics-Backend/Dataset/test/test_night_81.csv',
                             usecols=['result_timestamp','laeq','night_scale','night_hour','Date','Event_type',
                                    'Weight_Event_Type','Organizer','Respondents','Distance',
                                    'LC_HUMIDITY','LC_DWPTEMP','LC_WINDSPEED','weekday',
                                    'Holiday','downseason','Weight_respondent','Total_Event_Score'])
calverie_test = pd.read_csv('/Users/siucheung/School/Modern Data Analytics/Modern-Data-Analytics-Backend/Dataset/test/test_night_calverie.csv',
                             usecols=['result_timestamp','laeq','night_scale','night_hour','Date','Event_type',
                                    'Weight_Event_Type','Organizer','Respondents','Distance',
                                    'LC_HUMIDITY','LC_DWPTEMP','LC_WINDSPEED','weekday',
                                    'Holiday','downseason','Weight_respondent','Total_Event_Score'])
filosovia_test = pd.read_csv('/Users/siucheung/School/Modern Data Analytics/Modern-Data-Analytics-Backend/Dataset/test/test_night_filosovia.csv',
                             usecols=['result_timestamp','laeq','night_scale','night_hour','Date','Event_type',
                                    'Weight_Event_Type','Organizer','Respondents','Distance',
                                    'LC_HUMIDITY','LC_DWPTEMP','LC_WINDSPEED','weekday',
                                    'Holiday','downseason','Weight_respondent','Total_Event_Score'])
maxim_test = pd.read_csv('/Users/siucheung/School/Modern Data Analytics/Modern-Data-Analytics-Backend/Dataset/test/test_night_maxim.csv',
                             usecols=['result_timestamp','laeq','night_scale','night_hour','Date','Event_type',
                                    'Weight_Event_Type','Organizer','Respondents','Distance',
                                    'LC_HUMIDITY','LC_DWPTEMP','LC_WINDSPEED','weekday',
                                    'Holiday','downseason','Weight_respondent','Total_Event_Score'])
taste_test = pd.read_csv('/Users/siucheung/School/Modern Data Analytics/Modern-Data-Analytics-Backend/Dataset/test/test_night_taste.csv',
                             usecols=['result_timestamp','laeq','night_scale','night_hour','Date','Event_type',
                                    'Weight_Event_Type','Organizer','Respondents','Distance',
                                    'LC_HUMIDITY','LC_DWPTEMP','LC_WINDSPEED','weekday',
                                    'Holiday','downseason','Weight_respondent','Total_Event_Score'])
vrijthof_test = pd.read_csv('/Users/siucheung/School/Modern Data Analytics/Modern-Data-Analytics-Backend/Dataset/test/test_night_vrijthof.csv',
                             usecols=['result_timestamp','laeq','night_scale','night_hour','Date','Event_type',
                                    'Weight_Event_Type','Organizer','Respondents','Distance',
                                    'LC_HUMIDITY','LC_DWPTEMP','LC_WINDSPEED','weekday',
                                    'Holiday','downseason','Weight_respondent','Total_Event_Score'])
xior_test = pd.read_csv('/Users/siucheung/School/Modern Data Analytics/Modern-Data-Analytics-Backend/Dataset/test/test_night_xior.csv',
                             usecols=['result_timestamp','laeq','night_scale','night_hour','Date','Event_type',
                                    'Weight_Event_Type','Organizer','Respondents','Distance',
                                    'LC_HUMIDITY','LC_DWPTEMP','LC_WINDSPEED','weekday',
                                    'Holiday','downseason','Weight_respondent','Total_Event_Score'])

# %% [markdown]
# # EDA

# %%
def hist_sound(df):
    fig = px.histogram(df, x="laeq",nbins=50)
    fig.update_layout(title_text='Distribution of sound level')
    fig.show()
    return

# %%
def hist_humid(df):
    fig = px.histogram(df, x="LC_HUMIDITY",nbins=50)
    fig.update_layout(title_text='Distribution of humidity')
    fig.show()
    return

# %%
def hist_temp(df):
    fig = px.histogram(df, x="LC_DWPTEMP",nbins=50)
    fig.update_layout(title_text='Distribution of downtemp')
    fig.show()
    return

# %%
def hist_wind(df):
    fig = px.histogram(df, x="LC_WINDSPEED",nbins=50)
    fig.update_layout(title_text='Distribution of windspeed')
    fig.show()
    return

# %%
def line_wind(df):
    fig = px.line(df, x="result_timestamp", y="LC_WINDSPEED", title='windspeed')
    fig.show()
    return

# %%
def boxplot_sound_week(df): 
       fig = px.box(df, x="weekday", y="laeq")
       fig.update_xaxes(categoryorder='array', categoryarray= ['Monday', 'Tuesday', 'Wednesday',
       'Thursday','Friday', 'Saturday', 'Sunday'])
       fig.update_layout(title_text='boxplot of sound level for each day')
       fig.show()
       return

# %%
def boxplot_sound_nighthour(df):
        fig = px.box(df, x="night_hour", y="laeq")
        fig.update_xaxes(categoryorder='array', categoryarray= [0,0.33,0.67,1,1.33,1.67,2,2.33,2.67,3,3.33,
                3.67,4,4.33,4.67,5,5.33,5.67,6,6.33,
                6.67,7,7.33,7.67,8,
                8.33,8.67,9,9.33,9.67,
                10, 10.33,10.67,11, 11.33,
                11.67,12, 12.33, 12.67  ])
        fig.update_layout(title_text='sound level by nighthour')
        fig.show()    
        return

# %%
def boxplot_sound_hour(df):
    fig = px.box(df, x="Hour", y="laeq")
    fig.update_xaxes(categoryorder='array', categoryarray= ['19','20','21','22','23','0','1','2','3','4','5','6','7'])
    fig.update_layout(title_text='sound level by hour')
    fig.show()

# %%
def boxplot_sound_organ(df):
    fig = px.box(calverie_train, x="Organizer", y="laeq")
    fig.update_layout(title_text='sound level per organizer')
    fig.show()

# %%
def boxplot_sound_event(df):
    fig = px.box(calverie_train, x="Event_type", y="laeq")
    fig.update_layout(title_text='sound level per event type')
    fig.show()

# %%
def boxplot_sound_holiday(df):
    fig = px.box(calverie_train, x="Holiday", y="laeq")
    fig.update_layout(title_text='soundlevel depending on holiday')
    fig.show()

# %%
calverie_train.drop(['result_timestamp','night_scale'],axis=1).corr()
# Out:
#                               laeq  night_hour  Weight_Event_Type  \
# laeq                      1.000000   -0.486761           0.047736
# night_hour               -0.486761    1.000000           0.000281
# Weight_Event_Type         0.047736    0.000281           1.000000
# Respondents               0.067496    0.002022          -0.091265
# Distance                 -0.089302   -0.003378          -0.343293
# LC_HUMIDITY              -0.357205    0.286080          -0.145902
# LC_DWPTEMP                0.058413   -0.075315          -0.308883
# LC_WINDSPEED              0.075891    0.021286          -0.171001
# Holiday                  -0.049101    0.000206           0.074052
# downseason               -0.294236   -0.002032          -0.311699
# Weight_respondent         0.056793    0.000185          -0.048505
# Total_Event_Score         0.311720   -0.002145           0.316095
# Hour                      0.598278   -0.699075          -0.000324
# Event_type_Cantus         0.074619    0.000489           0.665335
# Event_type_Other          0.082143    0.000394          -0.566763
# Event_type_Party          0.028209   -0.002562          -0.570918
# Event_type_Party_Student  0.149997   -0.002665           0.448451
# Organizer_Ambiorix       -0.057487    0.000379          -0.192825
# Organizer_Crimen          0.067491    0.000294           0.190642
# Organizer_Ekonomika       0.077112    0.000423          -0.092871
# Organizer_HDR             0.085598   -0.004656           0.260935
# Organizer_LOKO           -0.009482    0.000178          -0.144563
# Organizer_Politica        0.082616    0.000379           0.158815
# Organizer_Recup           0.055621    0.000464           0.150041
# Organizer_Rumba           0.052445   -0.003136          -0.450633
# Organizer_VRG             0.067559    0.000437           0.351536
# Organizer_t Archief       0.026563    0.000254          -0.128270
# weekday_Friday           -0.041286    0.005773          -0.081724
# weekday_Monday           -0.059964    0.000641           0.176067
# weekday_Saturday         -0.124599    0.000551          -0.192825
# weekday_Sunday           -0.141477    0.000597           0.095640
# weekday_Thursday          0.183080   -0.007154          -0.076539
# weekday_Tuesday           0.001872    0.000663           0.155076
# weekday_Wednesday         0.108580    0.000767          -0.074723
#
#                           Respondents  Distance  LC_HUMIDITY  LC_DWPTEMP  \
# laeq                         0.067496 -0.089302    -0.357205    0.058413
# night_hour                   0.002022 -0.003378     0.286080   -0.075315
# Weight_Event_Type           -0.091265 -0.343293    -0.145902   -0.308883
# Respondents                  1.000000  0.210316     0.056859   -0.144773
# Distance                     0.210316  1.000000     0.016356    0.380653
# LC_HUMIDITY                  0.056859  0.016356     1.000000    0.003544
# LC_DWPTEMP                  -0.144773  0.380653     0.003544    1.000000
# LC_WINDSPEED                 0.123468 -0.102851     0.003614    0.050581
# Holiday                     -0.048338 -0.067156    -0.017884    0.104232
# downseason                  -0.106340  0.338450     0.233800    0.190035
# Weight_respondent            0.499005 -0.041766     0.111593   -0.142974
# Total_Event_Score            0.107673 -0.464791    -0.188972   -0.292034
# Hour                        -0.002334  0.003899    -0.287234    0.076370
# Event_type_Cantus           -0.093964 -0.185344    -0.189288   -0.324870
# Event_type_Other            -0.032923 -0.149347     0.051312   -0.027361
# Event_type_Party             0.123331  0.602760    -0.104709    0.263279
# Event_type_Party_Student    -0.043705 -0.402235    -0.068573    0.021383
# Organizer_Ambiorix          -0.187966 -0.149429    -0.004407    0.161355
# Organizer_Crimen            -0.092377 -0.110999    -0.114520   -0.106993
# Organizer_Ekonomika          0.237546 -0.153839    -0.011384   -0.142551
# Organizer_HDR               -0.135803 -0.218238    -0.006105    0.101676
# Organizer_LOKO              -0.052392 -0.064129     0.039419   -0.048993
# Organizer_Politica          -0.067193 -0.145269    -0.046808   -0.090535
# Organizer_Recup             -0.099433 -0.177703    -0.085017   -0.039759
# Organizer_Rumba              0.264569  0.769773    -0.073930    0.165788
# Organizer_VRG               -0.017859 -0.164494    -0.070901   -0.114974
# Organizer_t Archief         -0.064847 -0.100388    -0.106277    0.103074
# weekday_Friday               0.279175  0.246129     0.005307   -0.021164
# weekday_Monday              -0.108059 -0.197660     0.073041   -0.031610
# weekday_Saturday             0.100346  0.336933    -0.011724    0.001361
# weekday_Sunday              -0.091230 -0.056203    -0.015420   -0.036760
# weekday_Thursday             0.116245  0.048680     0.068967    0.009429
# weekday_Tuesday             -0.137703 -0.157450    -0.080720    0.017570
# weekday_Wednesday           -0.114568 -0.103822    -0.046256    0.048965
#
#                           LC_WINDSPEED   Holiday  downseason  \
# laeq                          0.075891 -0.049101   -0.294236
# night_hour                    0.021286  0.000206   -0.002032
# Weight_Event_Type            -0.171001  0.074052   -0.311699
# Respondents                   0.123468 -0.048338   -0.106340
# Distance                     -0.102851 -0.067156    0.338450
# LC_HUMIDITY                   0.003614 -0.017884    0.233800
# LC_DWPTEMP                    0.050581  0.104232    0.190035
# LC_WINDSPEED                  1.000000 -0.038563    0.013575
# Holiday                      -0.038563  1.000000    0.028669
# downseason                    0.013575  0.028669    1.000000
# Weight_respondent             0.201580 -0.056183   -0.116078
# Total_Event_Score            -0.008965 -0.033861   -0.616640
# Hour                          0.009653 -0.000238    0.002347
# Event_type_Cantus            -0.067848 -0.038231   -0.211379
# Event_type_Other              0.154626 -0.030753   -0.087222
# Event_type_Party             -0.030357 -0.080474    0.056900
# Event_type_Party_Student     -0.085118  0.136779   -0.407128
# Organizer_Ambiorix            0.081297 -0.029573    0.291555
# Organizer_Crimen             -0.037043 -0.022960   -0.144614
# Organizer_Ekonomika           0.060843 -0.033016   -0.141267
# Organizer_HDR                -0.064928  0.057734   -0.190436
# Organizer_LOKO                0.022111 -0.013919    0.062259
# Organizer_Politica            0.032234 -0.029573   -0.186263
# Organizer_Recup              -0.001842  0.204276   -0.197266
# Organizer_Rumba              -0.066507 -0.065728   -0.048257
# Organizer_VRG                -0.073232 -0.034104   -0.214802
# Organizer_t Archief          -0.029792 -0.019803   -0.124730
# weekday_Friday                0.006438 -0.044481    0.048156
# weekday_Monday               -0.103031  0.228695    0.017754
# weekday_Saturday              0.036105  0.061360    0.130012
# weekday_Sunday                0.055783 -0.046610    0.057872
# weekday_Thursday             -0.031226 -0.065247   -0.095920
# weekday_Tuesday              -0.072380 -0.051761   -0.024010
# weekday_Wednesday             0.109176 -0.059911   -0.082738
#
#                           Weight_respondent  Total_Event_Score      Hour  \
# laeq                               0.056793           0.311720  0.598278
# night_hour                         0.000185          -0.002145 -0.699075
# Weight_Event_Type                 -0.048505           0.316095 -0.000324
# Respondents                        0.499005           0.107673 -0.002334
# Distance                          -0.041766          -0.464791  0.003899
# LC_HUMIDITY                        0.111593          -0.188972 -0.287234
# LC_DWPTEMP                        -0.142974          -0.292034  0.076370
# LC_WINDSPEED                       0.201580          -0.008965  0.009653
# Holiday                           -0.056183          -0.033861 -0.000238
# downseason                        -0.116078          -0.616640  0.002347
# Weight_respondent                  1.000000           0.234431 -0.000213
# Total_Event_Score                  0.234431           1.000000  0.002477
# Hour                              -0.000213           0.002477  1.000000
# Event_type_Cantus                 -0.095997           0.320426 -0.000565
# Event_type_Other                  -0.036032           0.141432 -0.000455
# Event_type_Party                   0.055588          -0.031775  0.002958
# Event_type_Party_Student           0.027760           0.400299  0.003077
# Organizer_Ambiorix                -0.011193          -0.056125 -0.000437
# Organizer_Crimen                  -0.008649           0.221811 -0.000339
# Organizer_Ekonomika               -0.012534           0.230720 -0.000488
# Organizer_HDR                     -0.046417           0.081654  0.005377
# Organizer_LOKO                     0.045745           0.033897 -0.000206
# Organizer_Politica                -0.011193           0.254378 -0.000437
# Organizer_Recup                   -0.013788           0.226399 -0.000535
# Organizer_Rumba                   -0.017325          -0.046772  0.003622
# Organizer_VRG                     -0.012960           0.234110 -0.000504
# Organizer_t Archief                0.210679           0.112481 -0.000293
# weekday_Friday                     0.058784          -0.222483 -0.006666
# weekday_Monday                    -0.054516          -0.009827 -0.000740
# weekday_Saturday                   0.064477          -0.267143 -0.000636
# weekday_Sunday                    -0.106607          -0.168252 -0.000689
# weekday_Thursday                   0.139024           0.352828  0.008261
# weekday_Tuesday                   -0.074090          -0.009926 -0.000765
# weekday_Wednesday                 -0.052923           0.177320 -0.000886
#
#                           Event_type_Cantus  Event_type_Other  \
# laeq                               0.074619          0.082143
# night_hour                         0.000489          0.000394
# Weight_Event_Type                  0.665335         -0.566763
# Respondents                       -0.093964         -0.032923
# Distance                          -0.185344         -0.149347
# LC_HUMIDITY                       -0.189288          0.051312
# LC_DWPTEMP                        -0.324870         -0.027361
# LC_WINDSPEED                      -0.067848          0.154626
# Holiday                           -0.038231         -0.030753
# downseason                        -0.211379         -0.087222
# Weight_respondent                 -0.095997         -0.036032
# Total_Event_Score                  0.320426          0.141432
# Hour                              -0.000565         -0.000455
# Event_type_Cantus                  1.000000         -0.073007
# Event_type_Other                  -0.073007          1.000000
# Event_type_Party                  -0.191042         -0.153678
# Event_type_Party_Student          -0.183659         -0.147739
# Organizer_Ambiorix                -0.070205         -0.056474
# Organizer_Crimen                   0.109263         -0.043846
# Organizer_Ekonomika                0.215987          0.505255
# Organizer_HDR                     -0.058975         -0.084545
# Organizer_LOKO                    -0.033042          0.292864
# Organizer_Politica                 0.319215          0.178468
# Organizer_Recup                   -0.085957         -0.003539
# Organizer_Rumba                   -0.156036         -0.125518
# Organizer_VRG                      0.319694         -0.065127
# Organizer_t Archief               -0.047012         -0.037818
# weekday_Friday                    -0.013685         -0.084944
# weekday_Monday                     0.091220          0.005779
# weekday_Saturday                  -0.102095         -0.082127
# weekday_Sunday                    -0.021995         -0.035522
# weekday_Thursday                  -0.013784          0.045668
# weekday_Tuesday                    0.000188         -0.049348
# weekday_Wednesday                  0.043570          0.154615
#
#                           Event_type_Party  Event_type_Party_Student  \
# laeq                              0.028209                  0.149997
# night_hour                       -0.002562                 -0.002665
# Weight_Event_Type                -0.570918                  0.448451
# Respondents                       0.123331                 -0.043705
# Distance                          0.602760                 -0.402235
# LC_HUMIDITY                      -0.104709                 -0.068573
# LC_DWPTEMP                        0.263279                  0.021383
# LC_WINDSPEED                     -0.030357                 -0.085118
# Holiday                          -0.080474                  0.136779
# downseason                        0.056900                 -0.407128
# Weight_respondent                 0.055588                  0.027760
# Total_Event_Score                -0.031775                  0.400299
# Hour                              0.002958                  0.003077
# Event_type_Cantus                -0.191042                 -0.183659
# Event_type_Other                 -0.153678                 -0.147739
# Event_type_Party                  1.000000                 -0.386596
# Event_type_Party_Student         -0.386596                  1.000000
# Organizer_Ambiorix                0.367483                 -0.142067
# Organizer_Crimen                 -0.114735                  0.195011
# Organizer_Ekonomika              -0.164982                 -0.048851
# Organizer_HDR                    -0.221233                  0.543594
# Organizer_LOKO                   -0.069552                  0.015394
# Organizer_Politica               -0.147778                  0.019263
# Organizer_Recup                  -0.180937                  0.434238
# Organizer_Rumba                   0.816760                 -0.315756
# Organizer_VRG                    -0.170421                  0.191847
# Organizer_t Archief               0.246083                 -0.095135
# weekday_Friday                    0.114499                 -0.185128
# weekday_Monday                   -0.173237                  0.098897
# weekday_Saturday                  0.159753                 -0.206602
# weekday_Sunday                   -0.151703                  0.024003
# weekday_Thursday                  0.156196                  0.067665
# weekday_Tuesday                  -0.158450                  0.133724
# weekday_Wednesday                 0.041007                  0.012380
#
#                           Organizer_Ambiorix  Organizer_Crimen  \
# laeq                               -0.057487          0.067491
# night_hour                          0.000379          0.000294
# Weight_Event_Type                  -0.192825          0.190642
# Respondents                        -0.187966         -0.092377
# Distance                           -0.149429         -0.110999
# LC_HUMIDITY                        -0.004407         -0.114520
# LC_DWPTEMP                          0.161355         -0.106993
# LC_WINDSPEED                        0.081297         -0.037043
# Holiday                            -0.029573         -0.022960
# downseason                          0.291555         -0.144614
# Weight_respondent                  -0.011193         -0.008649
# Total_Event_Score                  -0.056125          0.221811
# Hour                               -0.000437         -0.000339
# Event_type_Cantus                  -0.070205          0.109263
# Event_type_Other                   -0.056474         -0.043846
# Event_type_Party                    0.367483         -0.114735
# Event_type_Party_Student           -0.142067          0.195011
# Organizer_Ambiorix                  1.000000         -0.042163
# Organizer_Crimen                   -0.042163          1.000000
# Organizer_Ekonomika                -0.060628         -0.047072
# Organizer_HDR                      -0.081299         -0.063120
# Organizer_LOKO                     -0.025559         -0.019844
# Organizer_Politica                 -0.054306         -0.042163
# Organizer_Recup                    -0.066491         -0.051624
# Organizer_Rumba                    -0.120699         -0.093711
# Organizer_VRG                      -0.062627         -0.048623
# Organizer_t Archief                -0.036366         -0.028234
# weekday_Friday                     -0.081683          0.009031
# weekday_Monday                      0.013058         -0.071390
# weekday_Saturday                   -0.078974         -0.061316
# weekday_Sunday                     -0.085592         -0.066453
# weekday_Thursday                    0.056509         -0.037410
# weekday_Tuesday                     0.007468          0.055546
# weekday_Wednesday                   0.122146          0.148910
#
#                           Organizer_Ekonomika  Organizer_HDR  Organizer_LOKO  \
# laeq                                 0.077112       0.085598       -0.009482
# night_hour                           0.000423      -0.004656        0.000178
# Weight_Event_Type                   -0.092871       0.260935       -0.144563
# Respondents                          0.237546      -0.135803       -0.052392
# Distance                            -0.153839      -0.218238       -0.064129
# LC_HUMIDITY                         -0.011384      -0.006105        0.039419
# LC_DWPTEMP                          -0.142551       0.101676       -0.048993
# LC_WINDSPEED                         0.060843      -0.064928        0.022111
# Holiday                             -0.033016       0.057734       -0.013919
# downseason                          -0.141267      -0.190436        0.062259
# Weight_respondent                   -0.012534      -0.046417        0.045745
# Total_Event_Score                    0.230720       0.081654        0.033897
# Hour                                -0.000488       0.005377       -0.000206
# Event_type_Cantus                    0.215987      -0.058975       -0.033042
# Event_type_Other                     0.505255      -0.084545        0.292864
# Event_type_Party                    -0.164982      -0.221233       -0.069552
# Event_type_Party_Student            -0.048851       0.543594        0.015394
# Organizer_Ambiorix                  -0.060628      -0.081299       -0.025559
# Organizer_Crimen                    -0.047072      -0.063120       -0.019844
# Organizer_Ekonomika                  1.000000      -0.090764       -0.028535
# Organizer_HDR                       -0.090764       1.000000       -0.038264
# Organizer_LOKO                      -0.028535      -0.038264        1.000000
# Organizer_Politica                  -0.060628      -0.081299       -0.025559
# Organizer_Recup                     -0.074232      -0.099541       -0.031294
# Organizer_Rumba                     -0.134751      -0.180694       -0.056808
# Organizer_VRG                       -0.069917      -0.093756       -0.029476
# Organizer_t Archief                 -0.040599      -0.054442       -0.017116
# weekday_Friday                      -0.039103      -0.122284       -0.038444
# weekday_Monday                       0.040223       0.086227        0.063805
# weekday_Saturday                    -0.088169      -0.118229       -0.037170
# weekday_Sunday                       0.055174      -0.010042       -0.040284
# weekday_Thursday                    -0.053794       0.020644        0.123416
# weekday_Tuesday                     -0.059620       0.076279       -0.044737
# weekday_Wednesday                    0.129887       0.033291       -0.051780
#
#                           Organizer_Politica  Organizer_Recup  \
# laeq                                0.082616         0.055621
# night_hour                          0.000379         0.000464
# Weight_Event_Type                   0.158815         0.150041
# Respondents                        -0.067193        -0.099433
# Distance                           -0.145269        -0.177703
# LC_HUMIDITY                        -0.046808        -0.085017
# LC_DWPTEMP                         -0.090535        -0.039759
# LC_WINDSPEED                        0.032234        -0.001842
# Holiday                            -0.029573         0.204276
# downseason                         -0.186263        -0.197266
# Weight_respondent                  -0.011193        -0.013788
# Total_Event_Score                   0.254378         0.226399
# Hour                               -0.000437        -0.000535
# Event_type_Cantus                   0.319215        -0.085957
# Event_type_Other                    0.178468        -0.003539
# Event_type_Party                   -0.147778        -0.180937
# Event_type_Party_Student            0.019263         0.434238
# Organizer_Ambiorix                 -0.054306        -0.066491
# Organizer_Crimen                   -0.042163        -0.051624
# Organizer_Ekonomika                -0.060628        -0.074232
# Organizer_HDR                      -0.081299        -0.099541
# Organizer_LOKO                     -0.025559        -0.031294
# Organizer_Politica                  1.000000        -0.066491
# Organizer_Recup                    -0.066491         1.000000
# Organizer_Rumba                    -0.120699        -0.147782
# Organizer_VRG                      -0.062627        -0.076679
# Organizer_t Archief                -0.036366        -0.044526
# weekday_Friday                     -0.081683        -0.100011
# weekday_Monday                      0.013058         0.063356
# weekday_Saturday                   -0.078974        -0.096695
# weekday_Sunday                     -0.030202         0.080811
# weekday_Thursday                    0.056509         0.074870
# weekday_Tuesday                     0.007468         0.012447
# weekday_Wednesday                   0.075713        -0.056907
#
#                           Organizer_Rumba  Organizer_VRG  Organizer_t Archief  \
# laeq                             0.052445       0.067559             0.026563
# night_hour                      -0.003136       0.000437             0.000254
# Weight_Event_Type               -0.450633       0.351536            -0.128270
# Respondents                      0.264569      -0.017859            -0.064847
# Distance                         0.769773      -0.164494            -0.100388
# LC_HUMIDITY                     -0.073930      -0.070901            -0.106277
# LC_DWPTEMP                       0.165788      -0.114974             0.103074
# LC_WINDSPEED                    -0.066507      -0.073232            -0.029792
# Holiday                         -0.065728      -0.034104            -0.019803
# downseason                      -0.048257      -0.214802            -0.124730
# Weight_respondent               -0.017325      -0.012960             0.210679
# Total_Event_Score               -0.046772       0.234110             0.112481
# Hour                             0.003622      -0.000504            -0.000293
# Event_type_Cantus               -0.156036       0.319694            -0.047012
# Event_type_Other                -0.125518      -0.065127            -0.037818
# Event_type_Party                 0.816760      -0.170421             0.246083
# Event_type_Party_Student        -0.315756       0.191847            -0.095135
# Organizer_Ambiorix              -0.120699      -0.062627            -0.036366
# Organizer_Crimen                -0.093711      -0.048623            -0.028234
# Organizer_Ekonomika             -0.134751      -0.069917            -0.040599
# Organizer_HDR                   -0.180694      -0.093756            -0.054442
# Organizer_LOKO                  -0.056808      -0.029476            -0.017116
# Organizer_Politica              -0.120699      -0.062627            -0.036366
# Organizer_Recup                 -0.147782      -0.076679            -0.044526
# Organizer_Rumba                  1.000000      -0.139193            -0.080826
# Organizer_VRG                   -0.139193       1.000000            -0.041938
# Organizer_t Archief             -0.080826      -0.041938             1.000000
# weekday_Friday                   0.191416      -0.043557            -0.054699
# weekday_Monday                  -0.204367       0.079169             0.014604
# weekday_Saturday                 0.239390      -0.091075            -0.052885
# weekday_Sunday                  -0.130277      -0.049859             0.023049
# weekday_Thursday                 0.124608       0.017322             0.047681
# weekday_Tuesday                 -0.183517       0.116408             0.010722
# weekday_Wednesday               -0.018345      -0.044979            -0.006304
#
#                           weekday_Friday  weekday_Monday  weekday_Saturday  \
# laeq                           -0.041286       -0.059964         -0.124599
# night_hour                      0.005773        0.000641          0.000551
# Weight_Event_Type              -0.081724        0.176067         -0.192825
# Respondents                     0.279175       -0.108059          0.100346
# Distance                        0.246129       -0.197660          0.336933
# LC_HUMIDITY                     0.005307        0.073041         -0.011724
# LC_DWPTEMP                     -0.021164       -0.031610          0.001361
# LC_WINDSPEED                    0.006438       -0.103031          0.036105
# Holiday                        -0.044481        0.228695          0.061360
# downseason                      0.048156        0.017754          0.130012
# Weight_respondent               0.058784       -0.054516          0.064477
# Total_Event_Score              -0.222483       -0.009827         -0.267143
# Hour                           -0.006666       -0.000740         -0.000636
# Event_type_Cantus              -0.013685        0.091220         -0.102095
# Event_type_Other               -0.084944        0.005779         -0.082127
# Event_type_Party                0.114499       -0.173237          0.159753
# Event_type_Party_Student       -0.185128        0.098897         -0.206602
# Organizer_Ambiorix             -0.081683        0.013058         -0.078974
# Organizer_Crimen                0.009031       -0.071390         -0.061316
# Organizer_Ekonomika            -0.039103        0.040223         -0.088169
# Organizer_HDR                  -0.122284        0.086227         -0.118229
# Organizer_LOKO                 -0.038444        0.063805         -0.037170
# Organizer_Politica             -0.081683        0.013058         -0.078974
# Organizer_Recup                -0.100011        0.063356         -0.096695
# Organizer_Rumba                 0.191416       -0.204367          0.239390
# Organizer_VRG                  -0.043557        0.079169         -0.091075
# Organizer_t Archief            -0.054699        0.014604         -0.052885
# weekday_Friday                  1.000000       -0.138304         -0.118787
# weekday_Monday                 -0.138304        1.000000         -0.133719
# weekday_Saturday               -0.118787       -0.133719          1.000000
# weekday_Sunday                 -0.128741       -0.144923         -0.124472
# weekday_Thursday               -0.180219       -0.202872         -0.174244
# weekday_Tuesday                -0.142970       -0.160941         -0.138230
# weekday_Wednesday              -0.165481       -0.186281         -0.159994
#
#                           weekday_Sunday  weekday_Thursday  weekday_Tuesday  \
# laeq                           -0.141477          0.183080         0.001872
# night_hour                      0.000597         -0.007154         0.000663
# Weight_Event_Type               0.095640         -0.076539         0.155076
# Respondents                    -0.091230          0.116245        -0.137703
# Distance                       -0.056203          0.048680        -0.157450
# LC_HUMIDITY                    -0.015420          0.068967        -0.080720
# LC_DWPTEMP                     -0.036760          0.009429         0.017570
# LC_WINDSPEED                    0.055783         -0.031226        -0.072380
# Holiday                        -0.046610         -0.065247        -0.051761
# downseason                      0.057872         -0.095920        -0.024010
# Weight_respondent              -0.106607          0.139024        -0.074090
# Total_Event_Score              -0.168252          0.352828        -0.009926
# Hour                           -0.000689          0.008261        -0.000765
# Event_type_Cantus              -0.021995         -0.013784         0.000188
# Event_type_Other               -0.035522          0.045668        -0.049348
# Event_type_Party               -0.151703          0.156196        -0.158450
# Event_type_Party_Student        0.024003          0.067665         0.133724
# Organizer_Ambiorix             -0.085592          0.056509         0.007468
# Organizer_Crimen               -0.066453         -0.037410         0.055546
# Organizer_Ekonomika             0.055174         -0.053794        -0.059620
# Organizer_HDR                  -0.010042          0.020644         0.076279
# Organizer_LOKO                 -0.040284          0.123416        -0.044737
# Organizer_Politica             -0.030202          0.056509         0.007468
# Organizer_Recup                 0.080811          0.074870         0.012447
# Organizer_Rumba                -0.130277          0.124608        -0.183517
# Organizer_VRG                  -0.049859          0.017322         0.116408
# Organizer_t Archief             0.023049          0.047681         0.010722
# weekday_Friday                 -0.128741         -0.180219        -0.142970
# weekday_Monday                 -0.144923         -0.202872        -0.160941
# weekday_Saturday               -0.124472         -0.174244        -0.138230
# weekday_Sunday                  1.000000         -0.188843        -0.149812
# weekday_Thursday               -0.188843          1.000000        -0.209716
# weekday_Tuesday                -0.149812         -0.209716         1.000000
# weekday_Wednesday              -0.173400         -0.242736        -0.192565
#
#                           weekday_Wednesday
# laeq                               0.108580
# night_hour                         0.000767
# Weight_Event_Type                 -0.074723
# Respondents                       -0.114568
# Distance                          -0.103822
# LC_HUMIDITY                       -0.046256
# LC_DWPTEMP                         0.048965
# LC_WINDSPEED                       0.109176
# Holiday                           -0.059911
# downseason                        -0.082738
# Weight_respondent                 -0.052923
# Total_Event_Score                  0.177320
# Hour                              -0.000886
# Event_type_Cantus                  0.043570
# Event_type_Other                   0.154615
# Event_type_Party                   0.041007
# Event_type_Party_Student           0.012380
# Organizer_Ambiorix                 0.122146
# Organizer_Crimen                   0.148910
# Organizer_Ekonomika                0.129887
# Organizer_HDR                      0.033291
# Organizer_LOKO                    -0.051780
# Organizer_Politica                 0.075713
# Organizer_Recup                   -0.056907
# Organizer_Rumba                   -0.018345
# Organizer_VRG                     -0.044979
# Organizer_t Archief               -0.006304
# weekday_Friday                    -0.165481
# weekday_Monday                    -0.186281
# weekday_Saturday                  -0.159994
# weekday_Sunday                    -0.173400
# weekday_Thursday                  -0.242736
# weekday_Tuesday                   -0.192565
# weekday_Wednesday                  1.000000

# %%
plt.figure(figsize=(20, 20))
# define the mask to set the values in the upper triangle to True
mask = np.triu(np.ones_like(calverie_train.drop(['result_timestamp','night_scale'],axis=1).corr(), dtype=np.bool))
heatmap = sns.heatmap(round(calverie_train.drop(['result_timestamp','night_scale'],axis=1).corr(),2), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Triangle Correlation Heatmap', fontdict={'fontsize':18}, pad=16)
# Out:
# /var/folders/f1/lckg4hvs6wv8tfcl39kys4j00000gn/T/ipykernel_12609/1550191556.py:3: DeprecationWarning:
#
# `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %% [markdown]
# # function

# %%
def rf_modeling(df_train, df_test):
   df_train['result_timestamp'] = pd.to_datetime(df_train['result_timestamp'])
   df_train['Hour'] = df_train['result_timestamp'].dt.hour
   df_train['laeq']= df_train['laeq'].interpolate(option='spline')
   df_train = pd.get_dummies(df_train, columns=['weekday'])
   df_train = df_train[['laeq','downseason','LC_HUMIDITY', 'LC_DWPTEMP', 'LC_WINDSPEED','Total_Event_Score', 'Hour','weekday_Friday', 'weekday_Monday',
       'weekday_Saturday', 'weekday_Sunday', 'weekday_Thursday',
       'weekday_Tuesday', 'weekday_Wednesday']]
   
   df_test['result_timestamp'] = pd.to_datetime(df_test['result_timestamp'])
   df_test['Hour'] = df_test['result_timestamp'].dt.hour
   df_test['laeq']= df_test['laeq'].interpolate(option='spline')
   df_test = pd.get_dummies(df_test, columns=['weekday'])
   df_test = df_test[['laeq','downseason','LC_HUMIDITY', 'LC_DWPTEMP', 'LC_WINDSPEED','Total_Event_Score', 'Hour','weekday_Friday', 'weekday_Monday',
       'weekday_Saturday', 'weekday_Sunday', 'weekday_Thursday',
       'weekday_Tuesday', 'weekday_Wednesday']]
   
   x_train = df_train.loc[:, df_train.columns != 'laeq']
   x_test = df_test.loc[:, df_test.columns != 'laeq']

   y_train = df_train['laeq']
   y_test = df_test['laeq']
    

    # the param to tune
   n_estimators = [int(x) for x in np.linspace(start = 10, stop = 1000, num = 10)]
   max_features = ['auto', 'sqrt']
   max_depth = [2,3,5,7,9]
   min_samples_split = [2, 5, 10, 20, 30]
   min_samples_leaf = [1, 2, 4, 8, 16]

   random_grid = {
      # The number of trees in the forest.
      'n_estimators': n_estimators,
      # The maximum depth of the tree
      'max_depth': max_depth,
      # The number of features to consider when looking for the best split
      'max_features': max_features,
      # The minimum number of samples required to split an internal node
      'min_samples_split': min_samples_split,
      # The minimum number of samples required to be at a leaf node
      'min_samples_leaf': min_samples_leaf}
   
   # tune the params
   rf = RandomForestRegressor()
   tuning_model = RandomizedSearchCV(estimator=rf, param_distributions=random_grid, n_iter=72, cv=5, verbose=1, n_jobs=-1) 
   # n_iter = Number of parameter settings that are sampled
    
   tuning_model.fit(x_train,y_train)
   print(tuning_model.best_params_)

   tuned_hyper_model= RandomForestRegressor(**tuning_model.best_params_)
   tuned_hyper_model.fit(x_train,y_train)
   tuned_pred=tuned_hyper_model.predict(x_test)

   plt.bar(x_train.columns, tuned_hyper_model.feature_importances_)
   plt.xticks(rotation=90)
   plt.show()

   print('R2: %.4f' %r2_score(y_test,tuned_pred))
   print('MSE: %.4f' %mean_squared_error(y_test,tuned_pred))

   print(tuned_pred)
   y_pred_rf = tuned_pred
   return y_pred_rf

# %%
def gbr_model(df_train,df_test):
    df_train['result_timestamp'] = pd.to_datetime(df_train['result_timestamp'])
    df_train['Hour'] = df_train['result_timestamp'].dt.hour
    df_train['laeq']= df_train['laeq'].interpolate(option='spline')
    df_train = pd.get_dummies(df_train, columns=['weekday'])
    df_train = df_train[['laeq','downseason','LC_HUMIDITY', 'LC_DWPTEMP', 'LC_WINDSPEED','Total_Event_Score', 'Hour','weekday_Friday', 'weekday_Monday',
       'weekday_Saturday', 'weekday_Sunday', 'weekday_Thursday',
       'weekday_Tuesday', 'weekday_Wednesday']]
   
    df_test['result_timestamp'] = pd.to_datetime(df_test['result_timestamp'])
    df_test['Hour'] = df_test['result_timestamp'].dt.hour
    df_test['laeq']= df_test['laeq'].interpolate(option='spline')
    df_test = pd.get_dummies(df_test, columns=['weekday'])
    df_test = df_test[['laeq','downseason','LC_HUMIDITY', 'LC_DWPTEMP', 'LC_WINDSPEED','Total_Event_Score', 'Hour','weekday_Friday', 'weekday_Monday',
       'weekday_Saturday', 'weekday_Sunday', 'weekday_Thursday',
       'weekday_Tuesday', 'weekday_Wednesday']]
   
    x_train = df_train.loc[:, df_train.columns != 'laeq']
    x_test = df_test.loc[:, df_test.columns != 'laeq']

    y_train = df_train['laeq']
    y_test = df_test['laeq']
    
    # parameters for gradien boosting regression
    params = {
    'learning_rate': [0.3, 0.2, 0.1, 0.05, 0.001],
    'n_estimators': [int(x) for x in np.linspace(start = 10, stop = 1000, num = 10)],
    'min_samples_split': [2, 5, 10, 20, 30],
    'min_samples_leaf': [1, 2, 4, 8, 16],
    'max_depth': [2, 3, 5, 7, 9],
    'max_features': ['auto', 'sqrt', 'log2']}

    gbr = GradientBoostingRegressor()
    tuning_model = RandomizedSearchCV(estimator=gbr, param_distributions=params,n_iter=200, cv=5, verbose=1, n_jobs=-1)
    tuning_model.fit(x_train,y_train)
    print(tuning_model.best_params_)
    
    tuned_hyper_model= GradientBoostingRegressor(**tuning_model.best_params_)
    tuned_hyper_model.fit(x_train,y_train)
    tuned_pred=tuned_hyper_model.predict(x_test)

    plt.bar(x_train.columns, tuned_hyper_model.feature_importances_)
    plt.xticks(rotation=90)
    plt.show()
    
    print('R2: %.4f' %r2_score(y_test,tuned_pred))
    print('MSE: %.4f' %mean_squared_error(y_test,tuned_pred))

    print(tuned_pred)
    y_pred_gbr = tuned_pred
    return y_pred_gbr

# %% [markdown]
# # Location: 81 (problematic)

# %%
x = rf_modeling(df_81_train,df_81_test)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# {'n_estimators': 780, 'min_samples_split': 30, 'min_samples_leaf': 8, 'max_features': 'auto', 'max_depth': 7}
# R2: -0.1239
# MSE: 40.8593
# [42.16506812 42.16506812 42.16422155 ... 46.54142829 46.54142829
#  46.54142829]

# %%
X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('Check It (Random Forest Regression Model)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %%
gbr_model(df_81_train,df_81_test)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# {'n_estimators': 230, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'auto', 'max_depth': 5, 'learning_rate': 0.05}
# R2: -0.0374
# MSE: 37.7148
# [43.5033774  43.5033774  43.24880958 ... 46.36991824 46.30089438
#  46.30089438]
# array([43.5033774 , 43.5033774 , 43.24880958, ..., 46.36991824,
#        46.30089438, 46.30089438])

# %%
x
# Out:
# array([42.53982952, 42.53982952, 42.5452315 , ..., 47.02451966,
#        47.02451966, 47.02451966])

# %% [markdown]
# # Location: Calverie

# %%
y_pred_rf = rf_modeling(calverie_train,calverie_test)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# {'n_estimators': 1000, 'min_samples_split': 30, 'min_samples_leaf': 8, 'max_features': 'auto', 'max_depth': 9}
# R2: 0.7038
# MSE: 10.5063
# [45.48388318 45.48388318 45.5044093  ... 48.79694784 48.84495632
#  48.84495632]

# %%
y_pred_gbr = gbr_model(calverie_train,calverie_test)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# {'n_estimators': 120, 'min_samples_split': 10, 'min_samples_leaf': 16, 'max_features': 'auto', 'max_depth': 5, 'learning_rate': 0.05}
# R2: 0.7308
# MSE: 9.5502
# [46.70136566 46.70136566 46.54074479 ... 49.16148151 49.16148151
#  49.16148151]

# %% [markdown]
# # location: filosovia

# %%
rf_modeling(filosovia_train,filosovia_test)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# {'n_estimators': 780, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 'auto', 'max_depth': 9}
# R2: 0.6840
# MSE: 13.1504
# [45.36222501 45.36222501 45.34778139 ... 48.05191765 48.0676193
#  48.0676193 ]
# array([45.36222501, 45.36222501, 45.34778139, ..., 48.05191765,
#        48.0676193 , 48.0676193 ])

# %%
gbr_model(filosovia_train,filosovia_test)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# {'n_estimators': 450, 'min_samples_split': 20, 'min_samples_leaf': 16, 'max_features': 'log2', 'max_depth': 5, 'learning_rate': 0.05}
# R2: 0.6605
# MSE: 14.1296
# [47.19895806 47.19895806 46.75827618 ... 48.52809302 48.4970593
#  48.4970593 ]
# array([47.19895806, 47.19895806, 46.75827618, ..., 48.52809302,
#        48.4970593 , 48.4970593 ])

# %% [markdown]
# # location: maxim

# %%
rf_modeling(maxim_train,maxim_test)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# {'n_estimators': 780, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 'auto', 'max_depth': 9}
# R2: 0.4269
# MSE: 27.0691
# [48.03487642 48.03487642 48.05471557 ... 51.55305294 51.90180927
#  51.93799434]
# array([48.03487642, 48.03487642, 48.05471557, ..., 51.55305294,
#        51.90180927, 51.93799434])

# %%
gbr_model(maxim_train,maxim_test)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# {'n_estimators': 450, 'min_samples_split': 20, 'min_samples_leaf': 16, 'max_features': 'log2', 'max_depth': 5, 'learning_rate': 0.05}
# R2: 0.4328
# MSE: 26.7942
# [48.88336447 48.88336447 49.11855969 ... 54.633833   54.5640891
#  53.86382853]
# array([48.88336447, 48.88336447, 49.11855969, ..., 54.633833  ,
#        54.5640891 , 53.86382853])

# %% [markdown]
# # location: taste

# %%
rf_modeling(taste_train,taste_test)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# {'n_estimators': 780, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 'auto', 'max_depth': 9}
# R2: 0.6383
# MSE: 4.9582
# [48.9607521  48.9607521  49.11953443 ... 51.03418849 51.05312814
#  51.05312814]
# array([48.9607521 , 48.9607521 , 49.11953443, ..., 51.03418849,
#        51.05312814, 51.05312814])

# %%
gbr_model(taste_train,taste_test)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# {'n_estimators': 230, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'auto', 'max_depth': 5, 'learning_rate': 0.05}
# R2: 0.6114
# MSE: 5.3258
# [49.63257082 49.63257082 49.48902951 ... 50.55705826 50.49805035
#  50.49805035]
# array([49.63257082, 49.63257082, 49.48902951, ..., 50.55705826,
#        50.49805035, 50.49805035])

# %% [markdown]
# # location: vrijthof (low)

# %%
rf_modeling(vrijthof_train,vrijthof_test)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# {'n_estimators': 780, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 9}
# R2: 0.1578
# MSE: 12.1382
# [43.41112607 43.41112607 43.24887505 ... 46.43781266 46.50969797
#  46.50969797]
# array([43.41112607, 43.41112607, 43.24887505, ..., 46.43781266,
#        46.50969797, 46.50969797])

# %%
gbr_model(vrijthof_train,vrijthof_test)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# {'n_estimators': 230, 'min_samples_split': 2, 'min_samples_leaf': 16, 'max_features': 'sqrt', 'max_depth': 2, 'learning_rate': 0.2}
# R2: 0.1898
# MSE: 11.6763
# [44.12185399 44.12185399 44.17530903 ... 48.84526065 48.84526065
#  48.84526065]
# array([44.12185399, 44.12185399, 44.17530903, ..., 48.84526065,
#        48.84526065, 48.84526065])

# %% [markdown]
# # location: xior

# %%
rf_modeling(xior_train,xior_test)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# {'n_estimators': 780, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 'auto', 'max_depth': 9}
# R2: 0.4491
# MSE: 15.5073
# [51.16412224 51.16412224 50.72577332 ... 53.54242313 53.57971429
#  53.57362556]
# array([51.16412224, 51.16412224, 50.72577332, ..., 53.54242313,
#        53.57971429, 53.57362556])

# %%
gbr_model(xior_train,xior_test)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# {'n_estimators': 780, 'min_samples_split': 5, 'min_samples_leaf': 16, 'max_features': 'sqrt', 'max_depth': 5, 'learning_rate': 0.05}
# R2: 0.4043
# MSE: 16.7704
# [49.45599682 49.45599682 49.93383467 ... 51.87376857 51.91155459
#  51.71429674]
# array([49.45599682, 49.45599682, 49.93383467, ..., 51.87376857,
#        51.91155459, 51.71429674])
